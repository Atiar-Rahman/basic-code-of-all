# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('1.jpeg')
img
# Out:
# array([[[157,  74, 177],
#         [157,  74, 177],
#         [158,  75, 178],
#         ...,
#         [205, 167, 189],
#         [205, 167, 189],
#         [203, 166, 186]],
#
#        [[154,  73, 176],
#         [157,  74, 177],
#         [158,  75, 178],
#         ...,
#         [202, 159, 186],
#         [202, 159, 186],
#         [200, 158, 183]],
#
#        [[154,  73, 176],
#         [154,  73, 176],
#         [157,  74, 177],
#         ...,
#         [197, 149, 185],
#         [196, 148, 184],
#         [195, 147, 183]],
#
#        ...,
#
#        [[ 21,  92, 180],
#         [ 21,  92, 180],
#         [ 22,  93, 181],
#         ...,
#         [109, 140, 171],
#         [111, 140, 171],
#         [112, 139, 173]],
#
#        [[ 21,  92, 180],
#         [ 21,  92, 180],
#         [ 22,  93, 181],
#         ...,
#         [116, 141, 175],
#         [118, 140, 176],
#         [118, 139, 177]],
#
#        [[ 21,  92, 180],
#         [ 21,  92, 180],
#         [ 22,  93, 181],
# ...

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)

# %%
# cv2.imshow("image",img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
cv2.imwrite('test.png',img)
# Out:
# True

# %% [markdown]
# web cam open q press

# %%
cap = cv2.VideoCapture(0)
while True:
    ret,frame = cap.read()
    
    cv2.imshow('frame',frame)
    if cv2.waitKey(40) & 0xFF ==ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# basic operation

# %% [markdown]
# resize

# %%
img1 = cv2.imread('2.png')
img_c = cv2.resize(img1,(300,300))
cv2.imshow('img1',img_c)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %% [markdown]
# crop img

# %%
img1.shape
# Out:
# (452, 455, 3)

# %%
croped_img = img1[60:200,90:400]
cv2.imshow('img',croped_img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %% [markdown]
# color space

# %%
import cv2
import os

# Initialize camera
cap = cv2.VideoCapture(0)

# Create output directory
output_dir = 'output_videos'
os.makedirs(output_dir, exist_ok=True)

# Get frame width and height from camera
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Define output file path
output_path = os.path.join(output_dir, 'rgb_saved.mp4')

# Define codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video = cv2.VideoWriter(output_path, fourcc, 20.0, (frame_width, frame_height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    cv2.imshow('frame', frame)
    video.write(frame)

    # Press 'q' to quit
    if cv2.waitKey(40) & 0xFF == ord('q'):
        break

# Release everything
cap.release()
video.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@18207.260] global cap_v4l.cpp:803 requestBuffers VIDEOIO(V4L2:/dev/video0): failed VIDIOC_REQBUFS: errno=19 (No such device)

# %%
import cv2
import os

# ক্যামেরা চালু
cap = cv2.VideoCapture(0)

# আউটপুট ফোল্ডার তৈরি
output_dir = 'output_videos'
os.makedirs(output_dir, exist_ok=True)

# ফ্রেমের সাইজ নেওয়া
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# আউটপুট ফাইল পাথ
output_path = os.path.join(output_dir, 'gray_saved1.mp4')

# কোডেক ডিফাইন (isColor=False মানে গ্রে ভিডিও)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video = cv2.VideoWriter(output_path, fourcc, 20.0, (frame_width, frame_height), isColor=False)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # ফ্রেমকে গ্রে করা
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Gray Frame', frame_gray)

    # সরাসরি গ্রে ফ্রেম রাইট করা
    video.write(frame_gray)

    if cv2.waitKey(40) & 0xFF == ord('q'):
        break

cap.release()
video.release()
cv2.destroyAllWindows()
