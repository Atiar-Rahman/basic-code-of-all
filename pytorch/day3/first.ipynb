# %%
print("hello world")
# Out:
# hello world

# %%
from datetime import datetime

now  = datetime.now()

print(now)
# Out:
# 2026-01-20 23:35:33.857231

# %%
from datetime import date, time, datetime, timedelta, timezone
print(now.year)
print(now.month)
print(now.day)
print(now.hour)
print(now.minute)
print(now.second)
print(datetime.now().day)
print(now)
# Out:
# 2026
# 1
# 20
# 23
# 35
# 33
# 20
# 2026-01-20 23:35:33.857231
