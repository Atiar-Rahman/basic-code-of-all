# %%
import torch

x = torch.rand(3,40)
x
# Out:
# tensor([[0.7884, 0.1836, 0.4578, 0.9925, 0.4673, 0.6700, 0.6527, 0.4594, 0.0642,
#          0.5950, 0.9815, 0.3112, 0.4345, 0.9803, 0.4332, 0.2612, 0.2206, 0.2720,
#          0.6049, 0.8542, 0.5237, 0.2297, 0.6676, 0.5479, 0.1107, 0.9122, 0.3838,
#          0.7398, 0.6899, 0.5989, 0.2988, 0.0587, 0.4115, 0.9276, 0.2214, 0.5259,
#          0.1455, 0.8635, 0.3040, 0.4007],
#         [0.1359, 0.9466, 0.0728, 0.6819, 0.9796, 0.1178, 0.1714, 0.0542, 0.9807,
#          0.8597, 0.8200, 0.1211, 0.0341, 0.2727, 0.7416, 0.5803, 0.1871, 0.7050,
#          0.6625, 0.3358, 0.6941, 0.3509, 0.7765, 0.4912, 0.5829, 0.6901, 0.6378,
#          0.8659, 0.0465, 0.1315, 0.9028, 0.5490, 0.7297, 0.4366, 0.2959, 0.4047,
#          0.1955, 0.2139, 0.5488, 0.9542],
#         [0.8595, 0.0309, 0.0093, 0.0803, 0.3880, 0.5807, 0.6295, 0.1866, 0.4750,
#          0.7907, 0.5597, 0.1199, 0.7706, 0.5545, 0.7250, 0.6346, 0.7686, 0.4190,
# ...

# %%
x.shape
# Out:
# torch.Size([3, 40])

# %%
if x._is_zerotensor:
    print('name')
# Out:
# name

# %%
x.device
# Out:
# device(type='cpu')

# %%
x = torch.tensor([1, 2, 3])
x.add_(0)
# Out:
# tensor([1, 2, 3])

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %%
# Out:
# ''
