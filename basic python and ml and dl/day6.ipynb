# %% [markdown]
# ## Factorial

# %%
def factorial(n):
    if n==0:
        return 1
    if n<0:
        return "imvalid number"
    return n*factorial(n-1)

# %%
result = factorial(3)
result
# Out:
# 6

# %%
factorial(10)
# Out:
# 3628800

# %%
factorial(1)
# Out:
# 1

# %%
factorial(0)
# Out:
# 1

# %%
factorial(-10)
# Out:
# 'imvalid number'
