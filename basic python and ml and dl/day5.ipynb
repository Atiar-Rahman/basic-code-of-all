# %%
def sum(a,b):
    print(a+b)

# %%
sum(1,2)
# Out:
# 3

# %%
sum(1,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sum(1,3,4)
#
# TypeError: sum() takes 2 positional arguments but 3 were given

# %%
def sum(*args):
    print(args)
    sum=0
    for i in args:
        sum+=i
    print(sum)

# %%
sum(1,2,3)
# Out:
# (1, 2, 3)
# 6

# %%
sum(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)
# 15

# %%
def func(**kwargs):
    
    for key,value in kwargs.items():
        print(f'{key}: {value}')
        
        
result = func(apple=2)
# Out:
# apple: 2

# %%
func(apple=4,orange=5)
# Out:
# apple: 4
# orange: 5
