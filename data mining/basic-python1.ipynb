# %% [markdown]
# #### basic python

# %%
print("hello world")
# Out:
# hello world

# %%
text = "my name is md atiar rahman"
if "my" in text:
    print("I am not a student")
# Out:
# I am not a student

# %%
first_name = "atiar"
last_name = "Rahaman"
full_name = first_name+" "+last_name
full_name
# Out:
# 'atiar Rahaman'

# %%
full_name = f"my {first_name} and {last_name}"
full_name
# Out:
# 'my atiar and Rahaman'

# %% [markdown]
# ##### Casting

# %%
x = str(34)
y = int(34.3)
z = float(2)

print(x,y,z)
# Out:
# 34 34 2.0

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# int

# %%
type(z)
# Out:
# float

# %%
name = input("Enter your name: ")
name
# Out:
# Enter your name:  atiar rahman
# 'atiar rahman'

# %%
age = input("Enter your age")
type(age)
x = int(age)
x
# Out:
# Enter your age 34
# 34

# %% [markdown]
# ##### Operations

# %% [markdown]
# ###### Arithmetic oeration

# %%
x=10
y=20
print(x+y)
print(x-y)
print(x*y)
print(x/y)
print(x%y)
print(x**y)
print(x//y)
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 100000000000000000000
# 0

# %% [markdown]
# ###### comparison operations

# %%
x=40
y=54

print(x==y)
print(x>=y)
print(x>y)
print(x<y)
print(x<=y)
print(x!=y)
# Out:
# False
# False
# False
# True
# True
# True

# %% [markdown]
# ###### logical operators

# %%
print(x>30 and y>34)
print(x<30 or y==45)
print(not x)
# Out:
# True
# False
# False

# %% [markdown]
# ##### List

# %%
# create a list
thislist = ['banana','apple','orange']
print(thislist)
# Out:
# ['banana', 'apple', 'orange']

# %%
thislist.append('34')

# %%
thislist
# Out:
# ['banana', 'apple', 'orange', '34']

# %%
thislist.remove('34')

# %%
thislist
# Out:
# ['banana', 'apple', 'orange']

# %%
thislist.pop()
# Out:
# 'orange'

# %%
thislist
# Out:
# ['banana', 'apple']

# %%
thislist.insert(2,"orange")

# %%
thislist
# Out:
# ['banana', 'apple', 'orange']

# %%
thislist.append("banana")

# %%
thislist
# Out:
# ['banana', 'apple', 'orange', 'banana']

# %%
len(thislist)
# Out:
# 4

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(len(thislist)):
    print(thislist[i])
# Out:
# banana
# apple
# orange
# banana

# %%
i=0
while(i<len(thislist)):
    print(thislist[i])
    i+=1
# Out:
# banana
# apple
# orange
# banana

# %%
thislist[::]
# Out:
# ['banana', 'apple', 'orange', 'banana']

# %%
thislist[::2]
# Out:
# ['banana', 'orange']

# %%
thislist[0:2]
# Out:
# ['banana', 'apple']

# %%
thislist[3:]
# Out:
# ['banana']

# %%
thislist[4:]
# Out:
# []

# %%
list2 = ['mango','coconat']
thislist.extend(list2)

# %%
thislist
# Out:
# ['banana', 'apple', 'orange', 'banana', 'mango', 'coconat']

# %%
thislist.reverse()

# %%
thislist
# Out:
# ['coconat', 'mango', 'banana', 'orange', 'apple', 'banana']

# %% [markdown]
# ##### condiational statement

# %%
a=10
b=20
if a<=b:
    print("a is less than b")
# Out:
# a is less than b

# %%
if a>3:
    print("a is greater than 3")
elif a>b:
    print("a is greater than b")
else:
    print("a and b are equal number")
# Out:
# a is greater than 3

# %%
if a>b:print("i")

# %%
for i in range(1,101):
    if i%2==0:
